# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("RGB.jpeg")`

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x451>

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (451, 474, 3)

# %%
cut = arr[: ,:,2]

# %%
plt.imshow(cut)
