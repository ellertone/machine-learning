# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("thor.jpeg")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (504, 474, 3)

# %%
cut = arr[:5, :5]

# %%
plt.imshow(cut)

# %%
plt.imshow(arr)

# %%
work = arr.copy()

# %%
work[:,:, [0,2]] = 0

# %%
plt.imshow(work)

# %%
gray = arr.mean(axis = 2)

# %%
plt.imshow(gray, cmap= "gray")
